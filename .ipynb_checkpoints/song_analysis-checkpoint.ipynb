# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
# Create pandas df from csv
song_details_df = pd.read_csv('top_100_details_test.csv')

# %%
# Create pandas df from SQL db

# sqlEngine = create_engine(
#     'mysql+pymysql://root:belly123@localhost:3306/luke_dev?charset=utf8mb4', pool_recycle=3600)
# db_connection = sqlEngine.connect()

# table_name = 'song_details'


# try:
#     song_details_df = pd.read_sql_table(table_name, db_connection, index_col='index')

# finally:
#     db_connection.close()

# %%
song_details_df
# Out:
#       Rank Length    Released    BPM     Key                   Genre  \
# 0        1   7:44  2020-04-17  122.0   A min  Melodic House & Techno
# 1        2   7:17  2020-03-13  124.0  C♯ maj                   House
# 2        3   5:26  2020-02-21  124.0   D min                   House
# 3        4   5:15  2020-04-03  124.0   A maj              Deep House
# 4        5   5:53  2020-03-27  125.0   A min              Tech House
# ...    ...    ...         ...    ...     ...                     ...
# 5095    96   5:42  2020-10-02  124.0   A min                   House
# 5096    97   4:31  2020-10-16   88.0   F min             Drum & Bass
# 5097    98   6:18  2020-09-01  123.0   F maj  Melodic House & Techno
# 5098    99   6:08  2020-08-28  128.0   A min              Tech House
# 5099   100   4:00  2020-10-09   87.0   A min             Drum & Bass
#
#                   Label        Date    Track_ID
# 0     RCA Records Label  2020-05-07         NaN
# 1             Different  2020-05-07         NaN
# 2                HouseU  2020-05-07         NaN
# 3         SPINNIN' DEEP  2020-05-07         NaN
# 4     Lovejuice Records  2020-05-07         NaN
# ...                 ...         ...         ...
# 5095             HouseU  2020-10-22  14162399.0
# 5096   Hospital Records  2020-10-22  14245816.0
# 5097    Counter Records  2020-10-22  14162348.0
# 5098               CLNE  2020-10-22  14049733.0
# 5099     Critical Music  2020-10-22  14273719.0
#
# [5100 rows x 9 columns]

# %%
song_details_df[['Key', 'Genre']]
# Out:
#          Key                   Genre
# 0      A min  Melodic House & Techno
# 1     C♯ maj                   House
# 2      D min                   House
# 3      A maj              Deep House
# 4      A min              Tech House
# ...      ...                     ...
# 5095   A min                   House
# 5096   F min             Drum & Bass
# 5097   F maj  Melodic House & Techno
# 5098   A min              Tech House
# 5099   A min             Drum & Bass
#
# [5100 rows x 2 columns]

# %%
attribute = 'Label'

start_date = '0'
end_date = '2020-10-22' # Default to today

song_details_df = song_details_df[start_date < song_details_df['Date']]

song_details_df = song_details_df[song_details_df['Date'] <= end_date]

song_details_df
# Out:
#       Rank Length    Released    BPM     Key                   Genre  \
# 0        1   7:44  2020-04-17  122.0   A min  Melodic House & Techno
# 1        2   7:17  2020-03-13  124.0  C♯ maj                   House
# 2        3   5:26  2020-02-21  124.0   D min                   House
# 3        4   5:15  2020-04-03  124.0   A maj              Deep House
# 4        5   5:53  2020-03-27  125.0   A min              Tech House
# ...    ...    ...         ...    ...     ...                     ...
# 5095    96   5:42  2020-10-02  124.0   A min                   House
# 5096    97   4:31  2020-10-16   88.0   F min             Drum & Bass
# 5097    98   6:18  2020-09-01  123.0   F maj  Melodic House & Techno
# 5098    99   6:08  2020-08-28  128.0   A min              Tech House
# 5099   100   4:00  2020-10-09   87.0   A min             Drum & Bass
#
#                   Label        Date    Track_ID
# 0     RCA Records Label  2020-05-07         NaN
# 1             Different  2020-05-07         NaN
# 2                HouseU  2020-05-07         NaN
# 3         SPINNIN' DEEP  2020-05-07         NaN
# 4     Lovejuice Records  2020-05-07         NaN
# ...                 ...         ...         ...
# 5095             HouseU  2020-10-22  14162399.0
# 5096   Hospital Records  2020-10-22  14245816.0
# 5097    Counter Records  2020-10-22  14162348.0
# 5098               CLNE  2020-10-22  14049733.0
# 5099     Critical Music  2020-10-22  14273719.0
#
# [5100 rows x 9 columns]

# %%
scored = song_details_df.assign(score = 1 / song_details_df['Rank'])
scored
# Out:
#       Rank Length    Released    BPM     Key                   Genre  \
# 0        1   7:44  2020-04-17  122.0   A min  Melodic House & Techno
# 1        2   7:17  2020-03-13  124.0  C♯ maj                   House
# 2        3   5:26  2020-02-21  124.0   D min                   House
# 3        4   5:15  2020-04-03  124.0   A maj              Deep House
# 4        5   5:53  2020-03-27  125.0   A min              Tech House
# ...    ...    ...         ...    ...     ...                     ...
# 5095    96   5:42  2020-10-02  124.0   A min                   House
# 5096    97   4:31  2020-10-16   88.0   F min             Drum & Bass
# 5097    98   6:18  2020-09-01  123.0   F maj  Melodic House & Techno
# 5098    99   6:08  2020-08-28  128.0   A min              Tech House
# 5099   100   4:00  2020-10-09   87.0   A min             Drum & Bass
#
#                   Label        Date    Track_ID     score
# 0     RCA Records Label  2020-05-07         NaN  1.000000
# 1             Different  2020-05-07         NaN  0.500000
# 2                HouseU  2020-05-07         NaN  0.333333
# 3         SPINNIN' DEEP  2020-05-07         NaN  0.250000
# 4     Lovejuice Records  2020-05-07         NaN  0.200000
# ...                 ...         ...         ...       ...
# 5095             HouseU  2020-10-22  14162399.0  0.010417
# 5096   Hospital Records  2020-10-22  14245816.0  0.010309
# 5097    Counter Records  2020-10-22  14162348.0  0.010204
# 5098               CLNE  2020-10-22  14049733.0  0.010101
# 5099     Critical Music  2020-10-22  14273719.0  0.010000
#
# [5100 rows x 10 columns]

# %%
grouped_song_details = scored.groupby(attribute)
grouped_song_details["score"].sum().sort_values(ascending=False)
# Out:
# Label
# Defected                35.910531
# Black Book Records      21.421631
# RCA Records Label       10.280205
# MUSE                    10.105469
# Hot Fuss                 9.422268
#                           ...
# Deep State               0.010204
# Island Records           0.010101
# Club Bad                 0.010101
# BeatFreak Recordings     0.010101
# PAWZ                     0.010101
# Name: score, Length: 335, dtype: float64

# %%
# Average BPM of genres
song_details_df.groupby("Genre")["BPM"].mean()
# Out:
# Genre
# Afro House                             122.592593
# Bass House                             125.552941
# Big Room                               128.758621
# Breaks                                 127.666667
# Dance                                  123.560000
# Dance / Electro Pop                    122.058824
# Deep House                             124.225490
# Drum & Bass                            111.120690
# Dubstep                                133.142857
# Electro House                          128.000000
# Electronica                            128.000000
# Electronica / Downtempo                129.000000
# Funky / Groove / Jackin' House         124.243590
# Future House                           127.000000
# Hard Techno                            140.000000
# House                                  124.711929
# Indie Dance                            121.333333
# Melodic House & Techno                 123.551213
# Minimal / Deep Tech                    127.292994
# Nu Disco / Disco                       121.964789
# Organic House / Downtempo              121.370370
# Progressive House                      123.171053
# Tech House                             126.338154
# Techno (Peak Time / Driving / Hard)    130.044843
# Techno (Peak Time / Driving)           130.696970
# Techno (Raw / Deep / Hypnotic)         132.880000
# Trance                                 135.504425
# Name: BPM, dtype: float64

# %%
# Average song length of genres

# %%
def convert_time_to_seconds(song_length):
    minute, seconds = song_length.split(":")
    return int(minute)*60 + int(seconds)

# %%
def convert_seconds_to_time(song_length):
    minute = str(int(song_length // 60))
    seconds = int(song_length % 60)
    return minute + ":" + "{:02d}".format(seconds)

# %%
song_length_seconds = song_details_df["Length"].map(convert_time_to_seconds, na_action='ignore')
with_seconds = song_details_df.assign(length_seconds = song_length_seconds)
with_seconds
# Out:
#       Rank Length    Released    BPM     Key                   Genre  \
# 0        1   7:44  2020-04-17  122.0   A min  Melodic House & Techno
# 1        2   7:17  2020-03-13  124.0  C♯ maj                   House
# 2        3   5:26  2020-02-21  124.0   D min                   House
# 3        4   5:15  2020-04-03  124.0   A maj              Deep House
# 4        5   5:53  2020-03-27  125.0   A min              Tech House
# ...    ...    ...         ...    ...     ...                     ...
# 5095    96   5:42  2020-10-02  124.0   A min                   House
# 5096    97   4:31  2020-10-16   88.0   F min             Drum & Bass
# 5097    98   6:18  2020-09-01  123.0   F maj  Melodic House & Techno
# 5098    99   6:08  2020-08-28  128.0   A min              Tech House
# 5099   100   4:00  2020-10-09   87.0   A min             Drum & Bass
#
#                   Label        Date    Track_ID  length_seconds
# 0     RCA Records Label  2020-05-07         NaN           464.0
# 1             Different  2020-05-07         NaN           437.0
# 2                HouseU  2020-05-07         NaN           326.0
# 3         SPINNIN' DEEP  2020-05-07         NaN           315.0
# 4     Lovejuice Records  2020-05-07         NaN           353.0
# ...                 ...         ...         ...             ...
# 5095             HouseU  2020-10-22  14162399.0           342.0
# 5096   Hospital Records  2020-10-22  14245816.0           271.0
# 5097    Counter Records  2020-10-22  14162348.0           378.0
# 5098               CLNE  2020-10-22  14049733.0           368.0
# 5099     Critical Music  2020-10-22  14273719.0           240.0
#
# [5100 rows x 10 columns]

# %%
# TODO: convert this series result to a more readable time
with_seconds.groupby(['Genre'])["length_seconds"].mean().map(convert_seconds_to_time, na_action='ignore')
# Out:
# Genre
# Afro House                             7:00
# Bass House                             4:11
# Big Room                               4:03
# Breaks                                 4:20
# Dance                                  5:02
# Dance / Electro Pop                    3:56
# Deep House                             6:26
# Drum & Bass                            4:31
# Dubstep                                3:04
# Electro House                          4:09
# Electronica                            4:06
# Electronica / Downtempo                5:52
# Funky / Groove / Jackin' House         4:55
# Future House                           5:11
# Hard Techno                            7:10
# House                                  6:01
# Indie Dance                            6:49
# Melodic House & Techno                 7:17
# Minimal / Deep Tech                    6:17
# Nu Disco / Disco                       6:02
# Organic House / Downtempo              7:53
# Progressive House                      7:04
# Tech House                             5:56
# Techno (Peak Time / Driving / Hard)    7:02
# Techno (Peak Time / Driving)           6:49
# Techno (Raw / Deep / Hypnotic)         5:42
# Trance                                 6:49
# Name: length_seconds, dtype: object

# %%
# Most popular key of genres
song_details_df.groupby("Genre")["Key"].max()
# Out:
# Genre
# Afro House                              G min
# Bass House                              G min
# Big Room                               F♯ min
# Breaks                                  F maj
# Dance                                  G♯ min
# Dance / Electro Pop                    D♯ maj
# Deep House                              G min
# Drum & Bass                            G♯ min
# Dubstep                                 F min
# Electro House                          G♯ maj
# Electronica                            D♯ min
# Electronica / Downtempo                G♯ min
# Funky / Groove / Jackin' House         F♯ min
# Future House                            G min
# Hard Techno                             A min
# House                                  G♯ min
# Indie Dance                            G♯ min
# Melodic House & Techno                 G♯ min
# Minimal / Deep Tech                     G min
# Nu Disco / Disco                        G min
# Organic House / Downtempo               G min
# Progressive House                      G♯ min
# Tech House                             G♯ min
# Techno (Peak Time / Driving / Hard)    G♯ min
# Techno (Peak Time / Driving)           G♯ min
# Techno (Raw / Deep / Hypnotic)          F maj
# Trance                                 G♯ min
# Name: Key, dtype: object

# %%
# Most popular genre of record label
song_details_df.groupby("Label")["Genre"].max()
# Out:
# Label
# 1605                                        Techno (Peak Time / Driving)
# 1985 Music                                                   Drum & Bass
# 7Wallace                                                      Bass House
# 8Bit                                                          Tech House
# A Tribe Called Kotori                          Organic House / Downtempo
#                                                        ...
# Whoyostro White                                      Minimal / Deep Tech
# Yellow Productions presents Africanism    Funky / Groove / Jackin' House
# Z Records                                                          House
# elrow Music                                                   Tech House
# fryhide                                           Melodic House & Techno
# Name: Genre, Length: 335, dtype: object
