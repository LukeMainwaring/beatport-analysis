# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
# Create pandas df from csv
song_details_df = pd.read_csv('top_100_details_test.csv')

# %%
# Create pandas df from SQL db

# sqlEngine = create_engine(
#     'mysql+pymysql://root:belly123@localhost:3306/luke_dev?charset=utf8mb4', pool_recycle=3600)
# db_connection = sqlEngine.connect()

# table_name = 'song_details'


# try:
#     song_details_df = pd.read_sql_table(table_name, db_connection, index_col='index')

# finally:
#     db_connection.close()

# %%
song_details_df
# Out:
#       Rank Length    Released    BPM     Key                      Genre  \
# 0        1   7:44  2020-04-17  122.0   A min     Melodic House & Techno
# 1        2   7:17  2020-03-13  124.0  C♯ maj                      House
# 2        3   5:26  2020-02-21  124.0   D min                      House
# 3        4   5:15  2020-04-03  124.0   A maj                 Deep House
# 4        5   5:53  2020-03-27  125.0   A min                 Tech House
# ...    ...    ...         ...    ...     ...                        ...
# 5295    96   5:54  2020-09-03  122.0  D♯ min                 Afro House
# 5296    97   6:19  2020-09-04  124.0   F maj                 Tech House
# 5297    98   6:09  2020-10-16  126.0   A min        Minimal / Deep Tech
# 5298    99   8:58  2020-10-16  123.0   E min  Organic House / Downtempo
# 5299   100   5:39  2020-10-09  121.0  F♯ min                 Afro House
#
#                         Label        Date    Track_ID
# 0           RCA Records Label  2020-05-07         NaN
# 1                   Different  2020-05-07         NaN
# 2                      HouseU  2020-05-07         NaN
# 3               SPINNIN' DEEP  2020-05-07         NaN
# 4           Lovejuice Records  2020-05-07         NaN
# ...                       ...         ...         ...
# 5295  Moon Harbour Recordings  2020-10-29  14067226.0
# 5296          La Pera Records  2020-10-29  13926068.0
# 5297        Solid Grooves Raw  2020-10-29  14313031.0
# 5298         All Day I Dream   2020-10-29  14272014.0
# 5299          MoBlack Records  2020-10-29  14279156.0
#
# [5300 rows x 9 columns]

# %% [markdown]
# ## Song Attribute Trends over time

# %%
attribute = 'Genre'

# start_date = '0'
start_date = '2020-10-18'
end_date = '2020-10-30' # Default to today

song_details_df = song_details_df[start_date < song_details_df['Date']]

song_details_df = song_details_df[song_details_df['Date'] <= end_date]

song_details_df
# Out:
#       Rank Length    Released    BPM     Key                      Genre  \
# 4900     1   5:19  2020-10-02  127.0   A min                 Tech House
# 4901     2   6:12  2020-10-09  125.0  A♯ maj                      House
# 4902     3   7:09  2020-09-25  124.0   F min                     Trance
# 4903     4   6:36  2020-09-18  126.0  A♯ maj                      House
# 4904     5   9:12  2020-09-11  125.0   A min     Melodic House & Techno
# ...    ...    ...         ...    ...     ...                        ...
# 5295    96   5:54  2020-09-03  122.0  D♯ min                 Afro House
# 5296    97   6:19  2020-09-04  124.0   F maj                 Tech House
# 5297    98   6:09  2020-10-16  126.0   A min        Minimal / Deep Tech
# 5298    99   8:58  2020-10-16  123.0   E min  Organic House / Downtempo
# 5299   100   5:39  2020-10-09  121.0  F♯ min                 Afro House
#
#                         Label        Date    Track_ID
# 4900                 Defected  2020-10-19  14257667.0
# 4901                 Defected  2020-10-19  14279080.0
# 4902           Smilax Records  2020-10-19  14269418.0
# 4903                     Sola  2020-10-19  14132025.0
# 4904             METAPHYSICAL  2020-10-19  14043445.0
# ...                       ...         ...         ...
# 5295  Moon Harbour Recordings  2020-10-29  14067226.0
# 5296          La Pera Records  2020-10-29  13926068.0
# 5297        Solid Grooves Raw  2020-10-29  14313031.0
# 5298         All Day I Dream   2020-10-29  14272014.0
# 5299          MoBlack Records  2020-10-29  14279156.0
#
# [400 rows x 9 columns]

# %%
scored = song_details_df.assign(score = 1 / song_details_df['Rank'])
scored
# Out:
#       Rank Length    Released    BPM     Key                      Genre  \
# 4900     1   5:19  2020-10-02  127.0   A min                 Tech House
# 4901     2   6:12  2020-10-09  125.0  A♯ maj                      House
# 4902     3   7:09  2020-09-25  124.0   F min                     Trance
# 4903     4   6:36  2020-09-18  126.0  A♯ maj                      House
# 4904     5   9:12  2020-09-11  125.0   A min     Melodic House & Techno
# ...    ...    ...         ...    ...     ...                        ...
# 5295    96   5:54  2020-09-03  122.0  D♯ min                 Afro House
# 5296    97   6:19  2020-09-04  124.0   F maj                 Tech House
# 5297    98   6:09  2020-10-16  126.0   A min        Minimal / Deep Tech
# 5298    99   8:58  2020-10-16  123.0   E min  Organic House / Downtempo
# 5299   100   5:39  2020-10-09  121.0  F♯ min                 Afro House
#
#                         Label        Date    Track_ID     score
# 4900                 Defected  2020-10-19  14257667.0  1.000000
# 4901                 Defected  2020-10-19  14279080.0  0.500000
# 4902           Smilax Records  2020-10-19  14269418.0  0.333333
# 4903                     Sola  2020-10-19  14132025.0  0.250000
# 4904             METAPHYSICAL  2020-10-19  14043445.0  0.200000
# ...                       ...         ...         ...       ...
# 5295  Moon Harbour Recordings  2020-10-29  14067226.0  0.010417
# 5296          La Pera Records  2020-10-29  13926068.0  0.010309
# 5297        Solid Grooves Raw  2020-10-29  14313031.0  0.010204
# 5298         All Day I Dream   2020-10-29  14272014.0  0.010101
# 5299          MoBlack Records  2020-10-29  14279156.0  0.010000
#
# [400 rows x 10 columns]

# %%
# TODO: decide if it's better to group by attribute then by Date, or by Date and then attribute

grouped_song_details = scored.groupby([attribute, 'Date'])
# grouped_song_details = scored.groupby(['Date', attribute])

# %%
grouped_song_details["score"].sum()
# grouped_song_details["score"].sum().sort_values(ascending=False)
# Out:
# Genre                           Date
# Afro House                      2020-10-19    0.040364
#                                 2020-10-22    0.036273
#                                 2020-10-26    0.011236
#                                 2020-10-29    0.020417
# Bass House                      2020-10-19    0.016129
#                                                 ...
# Techno (Raw / Deep / Hypnotic)  2020-10-29    0.013158
# Trance                          2020-10-19    0.424833
#                                 2020-10-22    1.035817
#                                 2020-10-26    1.028629
#                                 2020-10-29    1.052309
# Name: score, Length: 76, dtype: float64

# %% [markdown]
# ### Average BPM of genres

# %%
song_details_df.groupby(['Genre'])["BPM"].mean()
# Box and whisper plot or something with some ranges could be pretty interesting
# Out:
# Genre
# Afro House                        121.777778
# Bass House                        125.000000
# Big Room                          126.857143
# Breaks                            127.600000
# Dance / Electro Pop               120.000000
# Deep House                        125.166667
# Drum & Bass                        95.277778
# Electronica                       128.000000
# Funky / Groove / Jackin' House    124.764706
# House                             124.833333
# Indie Dance                       123.666667
# Melodic House & Techno            123.466667
# Minimal / Deep Tech               126.400000
# Nu Disco / Disco                  121.000000
# Organic House / Downtempo         121.705882
# Progressive House                 124.058824
# Tech House                        127.028571
# Techno (Peak Time / Driving)      129.863636
# Techno (Raw / Deep / Hypnotic)    133.000000
# Trance                            130.555556
# Name: BPM, dtype: float64

# %%
# With time dimension
song_details_df.groupby(['Genre', 'Date'])["BPM"].mean()
# Out:
# Genre                           Date
# Afro House                      2020-10-19    122.000000
#                                 2020-10-22    121.666667
#                                 2020-10-26    122.000000
#                                 2020-10-29    121.500000
# Bass House                      2020-10-19    125.000000
#                                                  ...
# Techno (Raw / Deep / Hypnotic)  2020-10-29    133.000000
# Trance                          2020-10-19    133.000000
#                                 2020-10-22    127.666667
#                                 2020-10-26    127.666667
#                                 2020-10-29    130.600000
# Name: BPM, Length: 76, dtype: float64

# %% [markdown]
# ### Average song length of genres

# %%
def convert_time_to_seconds(song_length):
    minute, seconds = song_length.split(":")
    return int(minute)*60 + int(seconds)

# %%
def convert_seconds_to_time(song_length):
    minute = str(int(song_length // 60))
    seconds = int(song_length % 60)
    return minute + ":" + "{:02d}".format(seconds)

# %%
song_length_seconds = song_details_df["Length"].map(convert_time_to_seconds, na_action='ignore')
with_seconds = song_details_df.assign(length_seconds = song_length_seconds)
with_seconds
# Out:
#       Rank Length    Released    BPM     Key                      Genre  \
# 4900     1   5:19  2020-10-02  127.0   A min                 Tech House
# 4901     2   6:12  2020-10-09  125.0  A♯ maj                      House
# 4902     3   7:09  2020-09-25  124.0   F min                     Trance
# 4903     4   6:36  2020-09-18  126.0  A♯ maj                      House
# 4904     5   9:12  2020-09-11  125.0   A min     Melodic House & Techno
# ...    ...    ...         ...    ...     ...                        ...
# 5295    96   5:54  2020-09-03  122.0  D♯ min                 Afro House
# 5296    97   6:19  2020-09-04  124.0   F maj                 Tech House
# 5297    98   6:09  2020-10-16  126.0   A min        Minimal / Deep Tech
# 5298    99   8:58  2020-10-16  123.0   E min  Organic House / Downtempo
# 5299   100   5:39  2020-10-09  121.0  F♯ min                 Afro House
#
#                         Label        Date    Track_ID  length_seconds
# 4900                 Defected  2020-10-19  14257667.0             319
# 4901                 Defected  2020-10-19  14279080.0             372
# 4902           Smilax Records  2020-10-19  14269418.0             429
# 4903                     Sola  2020-10-19  14132025.0             396
# 4904             METAPHYSICAL  2020-10-19  14043445.0             552
# ...                       ...         ...         ...             ...
# 5295  Moon Harbour Recordings  2020-10-29  14067226.0             354
# 5296          La Pera Records  2020-10-29  13926068.0             379
# 5297        Solid Grooves Raw  2020-10-29  14313031.0             369
# 5298         All Day I Dream   2020-10-29  14272014.0             538
# 5299          MoBlack Records  2020-10-29  14279156.0             339
#
# [400 rows x 10 columns]

# %%
with_seconds.groupby(['Genre'])["length_seconds"].mean().map(convert_seconds_to_time, na_action='ignore')
# Out:
# Genre
# Afro House                        6:33
# Bass House                        4:37
# Big Room                          3:12
# Breaks                            4:22
# Dance / Electro Pop               3:46
# Deep House                        6:34
# Drum & Bass                       4:23
# Electronica                       4:06
# Funky / Groove / Jackin' House    4:42
# House                             6:00
# Indie Dance                       6:15
# Melodic House & Techno            6:48
# Minimal / Deep Tech               6:48
# Nu Disco / Disco                  5:54
# Organic House / Downtempo         8:01
# Progressive House                 6:54
# Tech House                        5:49
# Techno (Peak Time / Driving)      7:01
# Techno (Raw / Deep / Hypnotic)    6:51
# Trance                            6:30
# Name: length_seconds, dtype: object

# %%
# With time dimension
with_seconds.groupby(['Genre', 'Date'])["length_seconds"].mean().map(convert_seconds_to_time, na_action='ignore')
# Out:
# Genre                           Date
# Afro House                      2020-10-19    6:42
#                                 2020-10-22    7:08
#                                 2020-10-26    5:54
#                                 2020-10-29    5:46
# Bass House                      2020-10-19    4:37
#                                               ...
# Techno (Raw / Deep / Hypnotic)  2020-10-29    6:51
# Trance                          2020-10-19    6:31
#                                 2020-10-22    6:28
#                                 2020-10-26    6:28
#                                 2020-10-29    6:30
# Name: length_seconds, Length: 76, dtype: object

# %% [markdown]
# ### Most popular key of genres

# %%
song_details_df.groupby(['Genre'])['Key'].max()
# Out:
# Genre
# Afro House                        F♯ min
# Bass House                         D min
# Big Room                           F maj
# Breaks                             D min
# Dance / Electro Pop                B maj
# Deep House                         G maj
# Drum & Bass                        G min
# Electronica                       D♯ min
# Funky / Groove / Jackin' House    D♯ min
# House                              F maj
# Indie Dance                       F♯ maj
# Melodic House & Techno             G min
# Minimal / Deep Tech                G min
# Nu Disco / Disco                  C♯ min
# Organic House / Downtempo         F♯ min
# Progressive House                  F maj
# Tech House                        G♯ min
# Techno (Peak Time / Driving)       G min
# Techno (Raw / Deep / Hypnotic)     B min
# Trance                             G maj
# Name: Key, dtype: object

# %%
# With time dimension
song_details_df.groupby(['Genre', 'Date'])["Key"].max()
# Out:
# Genre                           Date
# Afro House                      2020-10-19    F♯ min
#                                 2020-10-22     E min
#                                 2020-10-26    D♯ min
#                                 2020-10-29    F♯ min
# Bass House                      2020-10-19     D min
#                                                ...
# Techno (Raw / Deep / Hypnotic)  2020-10-29     B min
# Trance                          2020-10-19     G maj
#                                 2020-10-22     G maj
#                                 2020-10-26     G maj
#                                 2020-10-29     G maj
# Name: Key, Length: 76, dtype: object

# %%
# TODO: decide if you want this calculation to be based on score and apply this strategy
# scored.groupby("Genre")["Key", 'score'].apply(lambda x: print(x))

# %% [markdown]
# ### Most popular genre of record label

# %%
song_details_df.groupby("Label")["Genre"].max()
# song_details_df.groupby("Label")["Genre"].nlargest(1)
# Out:
# Label
# 1605                  Techno (Peak Time / Driving)
# 8Bit                                    Deep House
# All Day I Dream          Organic House / Downtempo
# All We Have Is Now    Techno (Peak Time / Driving)
# Anjunabeats                                 Trance
#                                   ...
# UNLEASHED                              Drum & Bass
# V Recordings                           Drum & Bass
# Viper Recordings                       Drum & Bass
# Watergate Records           Melodic House & Techno
# fryhide                     Melodic House & Techno
# Name: Genre, Length: 104, dtype: object

# %%
# With time dimension
song_details_df.groupby(['Label', 'Date'])["Genre"].max()
# Out:
# Label              Date
# 1605               2020-10-19    Techno (Peak Time / Driving)
#                    2020-10-22    Techno (Peak Time / Driving)
#                    2020-10-26    Techno (Peak Time / Driving)
#                    2020-10-29    Techno (Peak Time / Driving)
# 8Bit               2020-10-19                      Deep House
#                                              ...
# Watergate Records  2020-10-26          Melodic House & Techno
# fryhide            2020-10-19          Melodic House & Techno
#                    2020-10-22          Melodic House & Techno
#                    2020-10-26          Melodic House & Techno
#                    2020-10-29          Melodic House & Techno
# Name: Genre, Length: 318, dtype: object
