# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
# Create pandas df from csv
song_details_df = pd.read_csv('top_100_details_test.csv')

# %%
# Create pandas df from SQL db

# sqlEngine = create_engine(
#     'mysql+pymysql://root:belly123@localhost:3306/luke_dev?charset=utf8mb4', pool_recycle=3600)
# db_connection = sqlEngine.connect()

# table_name = 'song_details'


# try:
#     song_details_df = pd.read_sql_table(table_name, db_connection, index_col='index')

# finally:
#     db_connection.close()

# %%
song_details_df
# Out:
#       Rank Length    Released    BPM     Key                   Genre  \
# 0        1   7:44  2020-04-17  122.0   A min  Melodic House & Techno
# 1        2   7:17  2020-03-13  124.0  C♯ maj                   House
# 2        3   5:26  2020-02-21  124.0   D min                   House
# 3        4   5:15  2020-04-03  124.0   A maj              Deep House
# 4        5   5:53  2020-03-27  125.0   A min              Tech House
# ...    ...    ...         ...    ...     ...                     ...
# 4995    96   6:08  2020-08-28  128.0   A min              Tech House
# 4996    97   4:31  2020-10-06   86.0   C min             Drum & Bass
# 4997    98   4:14  2020-10-05  130.0   D min                  Breaks
# 4998    99   7:30  2019-06-14  120.0   E min  Melodic House & Techno
# 4999   100   4:00  2020-10-09   87.0   A min             Drum & Bass
#
#                   Label        Date    Track_ID
# 0     RCA Records Label  2020-05-07         NaN
# ...

# %%
song_details_df[['Key', 'Genre']]
# Out:
#          Key                   Genre
# 0      A min  Melodic House & Techno
# 1     C♯ maj                   House
# 2      D min                   House
# 3      A maj              Deep House
# 4      A min              Tech House
# ...      ...                     ...
# 4995   A min              Tech House
# 4996   C min             Drum & Bass
# 4997   D min                  Breaks
# 4998   E min  Melodic House & Techno
# 4999   A min             Drum & Bass
#
# [5000 rows x 2 columns]

# %%
attribute = 'Label'

start_date = '0'
end_date = '2020-10-20' # Default to today

song_details_df = song_details_df[start_date < song_details_df['Date']]

song_details_df = song_details_df[song_details_df['Date'] <= end_date]

song_details_df
# Out:
#       Rank Length    Released    BPM     Key                   Genre  \
# 0        1   7:44  2020-04-17  122.0   A min  Melodic House & Techno
# 1        2   7:17  2020-03-13  124.0  C♯ maj                   House
# 2        3   5:26  2020-02-21  124.0   D min                   House
# 3        4   5:15  2020-04-03  124.0   A maj              Deep House
# 4        5   5:53  2020-03-27  125.0   A min              Tech House
# ...    ...    ...         ...    ...     ...                     ...
# 4995    96   6:08  2020-08-28  128.0   A min              Tech House
# 4996    97   4:31  2020-10-06   86.0   C min             Drum & Bass
# 4997    98   4:14  2020-10-05  130.0   D min                  Breaks
# 4998    99   7:30  2019-06-14  120.0   E min  Melodic House & Techno
# 4999   100   4:00  2020-10-09   87.0   A min             Drum & Bass
#
#                   Label        Date    Track_ID
# 0     RCA Records Label  2020-05-07         NaN
# ...

# %%
scored = song_details_df.assign(score = 1 / song_details_df['Rank'])
scored
# Out:
#       Rank Length    Released    BPM     Key                   Genre  \
# 0        1   7:44  2020-04-17  122.0   A min  Melodic House & Techno
# 1        2   7:17  2020-03-13  124.0  C♯ maj                   House
# 2        3   5:26  2020-02-21  124.0   D min                   House
# 3        4   5:15  2020-04-03  124.0   A maj              Deep House
# 4        5   5:53  2020-03-27  125.0   A min              Tech House
# ...    ...    ...         ...    ...     ...                     ...
# 4995    96   6:08  2020-08-28  128.0   A min              Tech House
# 4996    97   4:31  2020-10-06   86.0   C min             Drum & Bass
# 4997    98   4:14  2020-10-05  130.0   D min                  Breaks
# 4998    99   7:30  2019-06-14  120.0   E min  Melodic House & Techno
# 4999   100   4:00  2020-10-09   87.0   A min             Drum & Bass
#
#                   Label        Date    Track_ID     score
# 0     RCA Records Label  2020-05-07         NaN  1.000000
# ...

# %%
grouped_song_details = scored.groupby(attribute)
grouped_song_details["score"].sum().sort_values(ascending=False)
# Out:
# Label
# Defected                35.005769
# Black Book Records      21.393767
# RCA Records Label       10.280205
# MUSE                    10.014560
# Hot Fuss                 9.407982
#                           ...
# Le Club Records          0.010204
# BeatFreak Recordings     0.010101
# Island Records           0.010101
# Club Bad                 0.010101
# PAWZ                     0.010101
# Name: score, Length: 330, dtype: float64

# %%
# Average BPM of genres
song_details_df.groupby("Genre")["BPM"].mean()
# Out:
# Genre
# Afro House                             122.647059
# Bass House                             125.559524
# Big Room                               128.888889
# Breaks                                 127.750000
# Dance                                  123.560000
# Dance / Electro Pop                    122.187500
# Deep House                             124.217822
# Drum & Bass                            111.656805
# Dubstep                                133.142857
# Electro House                          128.000000
# Electronica                            128.000000
# Electronica / Downtempo                129.000000
# Funky / Groove / Jackin' House         124.234783
# Future House                           127.000000
# Hard Techno                            140.000000
# House                                  124.706339
# Indie Dance                            121.276923
# Melodic House & Techno                 123.550546
# Minimal / Deep Tech                    127.313725
# ...

# %%
# Average song length of genres
# TODO: convert string of time length to seconds and back... this one is hard
def convert_to_seconds(song_lengths):
    return [(int(split[0])*60 + int(split[1])) for split in length.split() for length in song_lengths]
    
#     for length in song_lengths:
# #         print(l)
#         minute = int(length[0]) * 60
#         seconds = int(length[2:])
#         return minute + seconds


# convert_to_seconds('7:44')

# %%
# song_length_seconds = song_details_df.assign(
#     length_seconds = convert_to_seconds(length) for length in song_details_df["Length"])

song_length_seconds = song_details_df.assign(
    length_seconds = convert_to_seconds(song_details_df["Length"]))

# song_length_seconds = song_details_df.assign(
#     length_seconds = song_details_df["Length"] + 'a')

song_length_seconds

# # song_details_df.groupby("Genre")["Length"].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-252ef9c3155b> in <module>
#       3
#       4 song_length_seconds = song_details_df.assign(
# ----> 5     length_seconds = convert_to_seconds(song_details_df["Length"]))
#       6
#       7 # song_length_seconds = song_details_df.assign(
#
# <ipython-input-40-fcfea08311af> in convert_to_seconds(song_lengths)
#       2 # TODO: convert string of time length to seconds and back
#       3 def convert_to_seconds(song_lengths):
# ----> 4     return [(int(split[0])*60 + int(split[1]))  for length in song_lengths for split in length.split()]
#       5
#       6 #     for length in song_lengths:
#
# <ipython-input-40-fcfea08311af> in <listcomp>(.0)
#       2 # TODO: convert string of time length to seconds and back
#       3 def convert_to_seconds(song_lengths):
# ...
